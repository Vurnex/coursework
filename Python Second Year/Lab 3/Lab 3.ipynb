# %%
import numpy as np
import pandas as pd
from pandas import DataFrame, read_csv

# %%
data = pd.read_pickle("lab3-data.pkl")

# %%
data
# Out:
#                                                  title  \
# 0                                             "13 1/2"
# 1    "The Secret Diary of Hendrik Groen, 83 1/2 Yea...
# 2                              18 and Life on Skid Row
# 3                                  A Choice of Weapons
# 4                                          A Civil War
# ..                                                 ...
# 666                               You Know You Love Me
# 667                               You Know You Love Me
# 668                               You Know You Love Me
# 669                               You Know You Love Me
# 670                                           You Suck
#
#                                               subtitle            series  \
# 0                                                  NaN               NaN
# 1                                                  NaN               NaN
# 2                                                  NaN               NaN
# ...

# %%
df = pd.DataFrame(data)

# %%
df.iloc[:3]
# Out:
#                                                title subtitle series  \
# 0                                           "13 1/2"      NaN    NaN
# 1  "The Secret Diary of Hendrik Groen, 83 1/2 Yea...      NaN    NaN
# 2                            18 and Life on Skid Row      NaN    NaN
#
#             author my_rating avg_rating                 publisher    binding  \
# 0     Barr, Nevada       3.0        3.3            Vanguard Press  Hardcover
# 1   Groen, Hendrik       4.0       3.95  Grand Central Publishing  Hardcover
# 2  Bach, Sebastian       3.0       3.68          Dey Street Books  Hardcover
#
#    pages year_published month_read  month_read_num  year_read bookshelf
# 0    320           2009        May               5       2011      read
# 1    384           2014     August               8       2017      read
# 2    433           2016      April               4       2020      read

# %%
df.shape
# Out:
# (671, 14)

# %%
df.dtypes
# Out:
# title             object
# subtitle          object
# series            object
# author            object
# my_rating         object
# avg_rating        object
# publisher         object
# binding           object
# pages              int64
# year_published    object
# month_read        object
# month_read_num     int64
# year_read          int64
# bookshelf         object
# dtype: object

# %%
for col in df.columns:
    print(col)
# Out:
# title
# subtitle
# series
# author
# my_rating
# avg_rating
# publisher
# binding
# pages
# year_published
# month_read
# month_read_num
# year_read
# bookshelf

# %%
df.my_rating
# Out:
# 0      3.0
# 1      4.0
# 2      3.0
# 3      4.0
# 4      4.0
#       ...
# 666    3.0
# 667    3.0
# 668    3.0
# 669    3.0
# 670    3.0
# Name: my_rating, Length: 671, dtype: object

# %%
df.my_rating.isnull().sum()
# Out:
# 31

# %%
df.isnull().sum()
# Out:
# title               0
# subtitle          453
# series            549
# author              0
# my_rating          31
# avg_rating          0
# publisher           2
# binding             0
# pages               0
# year_published      0
# month_read          0
# month_read_num      0
# year_read           0
# bookshelf           0
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 1035

# %%
df = df.dropna(subset=['my_rating','avg_rating','year_published'])

# %%
df.isnull().sum().sum()
# Out:
# 958

# %%
df.my_rating.isnull().sum()
# Out:
# 0

# %%
df.avg_rating.isnull().sum()
# Out:
# 0

# %%
df.year_published.isnull().sum()
# Out:
# 0

# %%
df.dtypes
# Out:
# title             object
# subtitle          object
# series            object
# author            object
# my_rating         object
# avg_rating        object
# publisher         object
# binding           object
# pages              int64
# year_published    object
# month_read        object
# month_read_num     int64
# year_read          int64
# bookshelf         object
# dtype: object

# %%
df['my_rating'] = df['my_rating'].astype("float")

# %%
df['avg_rating'] = df['avg_rating'].astype("float")

# %%
df['year_published'] = df['year_published'].astype("int64")

# %%
df.dtypes
# Out:
# title              object
# subtitle           object
# series             object
# author             object
# my_rating         float64
# avg_rating        float64
# publisher          object
# binding            object
# pages               int64
# year_published      int64
# month_read         object
# month_read_num      int64
# year_read           int64
# bookshelf          object
# dtype: object

# %%
df = df.fillna('')

# %%
df
# Out:
#                                                  title  \
# 0                                             "13 1/2"
# 1    "The Secret Diary of Hendrik Groen, 83 1/2 Yea...
# 2                              18 and Life on Skid Row
# 3                                  A Choice of Weapons
# 4                                          A Civil War
# ..                                                 ...
# 666                               You Know You Love Me
# 667                               You Know You Love Me
# 668                               You Know You Love Me
# 669                               You Know You Love Me
# 670                                           You Suck
#
#                                               subtitle            series  \
# 0
# 1
# 2
# 3
# 4    Army vs. Navy - A Year Inside College Football...
# ..                                                 ...               ...
# 666                                                      Gossip Girl, #2
# ...

# %%
df.isnull().sum()
# Out:
# title             0
# subtitle          0
# series            0
# author            0
# my_rating         0
# avg_rating        0
# publisher         0
# binding           0
# pages             0
# year_published    0
# month_read        0
# month_read_num    0
# year_read         0
# bookshelf         0
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
df.dtypes
# Out:
# title              object
# subtitle           object
# series             object
# author             object
# my_rating         float64
# avg_rating        float64
# publisher          object
# binding            object
# pages               int64
# year_published      int64
# month_read         object
# month_read_num      int64
# year_read           int64
# bookshelf          object
# dtype: object

# %%
testValue = df[df['year_published'] <= 0]

# %%
testValue
# Out:
#                      title      subtitle            series  \
# 61                 Bad Dog  A Love Story
# 85              Calico Joe
# 122             Die Trying                Jack Reacher, #2
# 169       Garden of Beasts
# 250             Life of Pi
# 461      The First Husband
# 491  The King of Methlehem       A Novel
# 667   You Know You Love Me                 Gossip Girl, #2
#
#                    author  my_rating  avg_rating         publisher    binding  \
# 61           Kihn, Martin        5.0        3.79          Pantheon  Hardcover
# 85          Grisham, John        4.0        3.78         Doubleday  Hardcover
# 122            Child, Lee        4.0       14.03              Jove  Paperback
# 169       Deaver, Jeffery        1.0        3.84  Simon & Schuster  Hardcover
# 250          Martel, Yann        5.0        3.90          Harcourt  Hardcover
# 461           Dave, Laura        3.0        3.54            Viking  Hardcover
# ...

# %%
testValue2 = df[(df.my_rating <= 0) | (df.my_rating >= 5)]

# %%
testValue2
# Out:
#                                title  \
# 5                  A Clash of Kings
# 9                      A Fan's Notes
# 12                 A Game of Thrones
# 13            A Gathering of Old Men
# 19          A Question of Attraction
# ..                               ...
# 600                   The Weatherman
# 606  The World's Strongest Librarian
# 633               Uneducated Guesses
# 654                Willful Ignorance
# 659                     Word by Word
#
#                                               subtitle  \
# 5
# 9
# 12
# 13
# 19
# ..                                                 ...
# 600
# 606  A Memoir of Tourette's, Faith, Strength, and t...
# 633  Using Evidence to Uncover Misguided Education ...
# 654                      The Mismeasure of Uncertainty
# 659                    The Secret Life of Dictionaries
#
#                          series                author  my_rating  avg_rating  \
# ...

# %%
testValue3 = df[(df.avg_rating <= 0) | (df.avg_rating >= 5)]

# %%
testValue3
# Out:
#                              title  \
# 106                Dark Homecoming
# 115             Dear Mr. Knightley
# 122                     Die Trying
# 135               Dreyer's English
# 150            Family Resemblances
# 182                        Gretzky
# 191  Headspin, Headshots & History
# 236  Last Night at Chateau Marmont
# 372                Skate for Goal!
# 425        The Book of Lost Things
# 482           The Imperfectionists
# 491          The King of Methlehem
# 668           You Know You Love Me
# 669           You Know You Love Me
#
#                                               subtitle            series  \
# 106
# 115
# 122                                                     Jack Reacher, #2
# 135      An Utterly Correct Guide to Clarity and Style
# 150
# 182
# 191                  Growing Up in Twin Cities Hip Hop
# 236
# 372  Highlights from Minnesota's State Hockey Tourn...
# 425
# 482
# 491                                            A Novel
# ...

# %%
df = df[df['year_published'] >= 0].copy()

df = df[(df['my_rating'] >= 0)].copy()

df = df[(df['my_rating'] <= 5)].copy()

df = df[(df['avg_rating'] >= 0)].copy()

df = df[(df['avg_rating'] <= 5)].copy()

# %%
df
# Out:
#                                                  title  \
# 0                                             "13 1/2"
# 1    "The Secret Diary of Hendrik Groen, 83 1/2 Yea...
# 2                              18 and Life on Skid Row
# 3                                  A Choice of Weapons
# 4                                          A Civil War
# ..                                                 ...
# 662                              Wunnerful, Wunnerful!
# 663                                                 XO
# 664                                         xo Orpheus
# 666                               You Know You Love Me
# 670                                           You Suck
#
#                                               subtitle             series  \
# 0
# 1
# 2
# 3
# 4    Army vs. Navy - A Year Inside College Football...
# ..                                                 ...                ...
# 662                 The Autobiography of Lawrence Welk
# ...

# %%
df.shape
# Out:
# (622, 14)

# %%
dfRating = df.loc[df.groupby('year_published', sort=True)['avg_rating'].idxmax()]

# %%
dfRating
# Out:
#                                                title  \
# 291  Narratives of the Wreck of the Whale-Ship Essex
# 30         A Week on the Concord and Merrimac Rivers
# 649                       Where Angels Fear To Tread
# 455                            The Elements of Style
# 130                 Down and Out in Paris and London
# 248                     Lexicon of Musical Invective
# 280                              Murder in Minnesota
# 9                                      A Fan's Notes
# 289                                   My Turn at Bat
# 311              On Writing, Editing, and Publishing
# 309           On Equality of Educational Opportunity
# 474                         The Great American Novel
# 614                       Tom Mix Died For Your Sins
# 630                                        Typologia
# 55                                         At Random
# 263                                      Max Perkins
# 578                      The Storyteller's Nashville
# ...

# %%
dfRating.shape
# Out:
# (58, 14)

# %%
groupby_rating = dfRating.groupby(['year_published', 'title'], sort=True)['avg_rating'].max()

# %%
print(groupby_rating.to_string())
# Out:
# year_published  title
# 1821            Narratives of the Wreck of the Whale-Ship Essex    3.90
# 1849            A Week on the Concord and Merrimac Rivers          3.71
# 1905            Where Angels Fear To Tread                         3.57
# 1918            The Elements of Style                              4.18
# 1933            Down and Out in Paris and London                   4.11
# 1953            Lexicon of Musical Invective                       4.36
# 1962            Murder in Minnesota                                3.63
# 1968            A Fan's Notes                                      4.08
# 1969            My Turn at Bat                                     4.07
# 1971            On Writing, Editing, and Publishing                3.93
# 1972            On Equality of Educational Opportunity             4.00
# 1973            The Great American Novel                           3.64
# 1975            Tom Mix Died For Your Sins                         3.47
# ...
